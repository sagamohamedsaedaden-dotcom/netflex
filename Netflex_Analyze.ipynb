# %%
import pandas as pd 
import plotly.express as px
import plotly.graph_objects as go
import plotly.io as pio
netflix_data = pd.read_csv('netflix_content.csv')

# %%
pio.renderers.default = "notebook"

#This line sets the default renderer for Plotly to "notebook".
#That means any Plotly chart you create will automatically display inside your Jupyter Notebook

# %%
netflix_data.dtypes
# Out:
# Title                   object
# Available Globally?     object
# Release Date            object
# Hours Viewed           float64
# Language Indicator      object
# Content Type            object
# dtype: object

# %%
netflix_data['Hours Viewed']=netflix_data['Hours Viewed'].replace(',','',regex=True).astype(float)
netflix_data
# Out:
#                                               Title Available Globally?  \
# 0                         The Night Agent: Season 1                 Yes
# 1                         Ginny & Georgia: Season 2                 Yes
# 2                The Glory: Season 1 // 더 글로리: 시즌 1                 Yes
# 3                               Wednesday: Season 1                 Yes
# 4               Queen Charlotte: A Bridgerton Story                 Yes
# ...                                             ...                 ...
# 24807            We Are Black and British: Season 1                  No
# 24808             Whitney Cummings: Can I Touch It?                 Yes
# 24809                       Whitney Cummings: Jokes                  No
# 24810  Whose Vote Counts, Explained: Limited Series                 Yes
# 24811   Zach Galifianakis: Live at the Purple Onion                  No
#
#       Release Date  Hours Viewed Language Indicator Content Type
# 0       2023-03-23   812100000.0            English         Show
# 1       2023-01-05   665100000.0            English         Show
# 2       2022-12-30   622800000.0             Korean         Show
# 3       2022-11-23   507700000.0            English         Show
# 4       2023-05-04   503000000.0            English        Movie
# ...            ...           ...                ...          ...
# 24807          NaN      100000.0            English         Show
# 24808   2019-07-30      100000.0            English        Movie
# 24809   2022-07-26      100000.0            English        Movie
# 24810   2020-09-28      100000.0            English        Movie
# 24811          NaN      100000.0            English        Movie
#
# [24812 rows x 6 columns]

# %%
content_type=netflix_data.groupby('Content Type')['Hours Viewed'].sum()
content_type
# Out:
# Content Type
# Movie    5.063780e+10
# Show     1.077641e+11
# Name: Hours Viewed, dtype: float64

# %%
fig= go.Figure(data=[go.Bar(x=content_type.index, y=content_type.values, marker_color=['skyblue','salmon'])])

fig.update_layout(title='Total Viewership Hours by Content Type',
xaxis_title='content_type',yaxis_title='total hours viewed(in billions)',height=400,width=800)

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="bc82c2b7-c441-425c-be2e-9dc2158d45bc" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("bc82c2b7-c441-425c-be2e-9dc2158d45bc")) {                    Plotly.newPlot(                        "bc82c2b7-c441-425c-be2e-9dc2158d45bc",                        [{"marker":{"color":["skyblue","salmon"]},"x":["Movie","Show"],"y":{"dtype":"f8","bdata":"AACABH+UJ0IAAKCrPRc5Qg=="},"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}]," ...
#
# var gd = document.getElementById('bc82c2b7-c441-425c-be2e-9dc2158d45bc');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = win

# %% [markdown]
# ## analyze the distribution of viewership across different languages

# %%
language_of_content=netflix_data.groupby('Language Indicator')['Hours Viewed'].sum().sort_values(ascending=False)
language_of_content
# Out:
# Language Indicator
# English        1.244417e+11
# Korean         1.537840e+10
# Non-English    1.043910e+10
# Japanese       7.102000e+09
# Hindi          9.261000e+08
# Russian        1.146000e+08
# Name: Hours Viewed, dtype: float64

# %%
fig=go.Figure(data=[go.Bar(x=language_of_content.index, y=language_of_content.values,
marker_color='skyblue' )])

fig.update_layout(title='Total Viewership Hours by language',
xaxis_title='language',yaxis_title='total hours viewed',height=400,
width=800,xaxis_tickangle=45
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="36807b0f-d4cd-461f-af4c-250a684c1ea4" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("36807b0f-d4cd-461f-af4c-250a684c1ea4")) {                    Plotly.newPlot(                        "36807b0f-d4cd-461f-af4c-250a684c1ea4",                        [{"marker":{"color":"skyblue"},"x":["English","Korean","Non-English","Japanese","Hindi","Russian"],"y":{"dtype":"f8","bdata":"AACgpk35PEIAAAAY\u002fqQMQgAAADPAcQNCAAAAuP50+kEAAAAQlZnLQQAAAAChUptB"},"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"out ...
#
# var gd = document.getElementById('36807b0f-d4cd-461f-af4c-250a684c1ea4');
# var x = new M

# %%
netflix_data['Release Date'] = pd.to_datetime(netflix_data['Release Date'])

# %%
netflix_data['Release Month'] = netflix_data['Release Date'].dt.month.astype('Int64')
monthly_viewership = netflix_data.groupby('Release Month')['Hours Viewed'].sum()
monthly_viewership
# Out:
# Release Month
# 1     7.271600e+09
# 2     7.103700e+09
# 3     7.437100e+09
# 4     6.865700e+09
# 5     7.094600e+09
# 6     8.522000e+09
# 7     6.524800e+09
# 8     6.817800e+09
# 9     7.262200e+09
# 10    8.123200e+09
# 11    7.749500e+09
# 12    1.005580e+10
# Name: Hours Viewed, dtype: float64

# %%
fig = go.Figure(data=[
    go.Scatter(
        x=monthly_viewership.index,
        y=monthly_viewership.values,
        mode='lines+markers',
        marker_color='blue')
    
])

fig.update_layout(
    title='Total Viewership Hours by Release Month ',
    xaxis_title='Month',yaxis_title='Total Hours Viewed (in billions)',
    xaxis=dict(tickmode='array',
    tickvals=list(range(1,13)),
    ticktext=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
            'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
    ))

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="f2fe4e77-8439-4870-abf0-cb0e3d3c634d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("f2fe4e77-8439-4870-abf0-cb0e3d3c634d")) {                    Plotly.newPlot(                        "f2fe4e77-8439-4870-abf0-cb0e3d3c634d",                        [{"marker":{"color":"blue"},"mode":"lines+markers","x":{"dtype":"i1","bdata":"AQIDBAUGBwgJCgsM"},"y":{"dtype":"f8","bdata":"AAAA+LwW+0EAAADCnXb6QQAAAD6StPtBAAAASqST+UEAAAAU8G36QQAAAGg2v\u002f9BAAAAwIhO+EEAAAD09WX5QQAAAAzGDftBAAAAIONC\u002fkEAAADGf978QQAAAKb6ugJC"},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"t ...

# %% [markdown]
# ## Analyze viewership trends by content type:

# %%
top_5=netflix_data.nlargest(5,'Hours Viewed')
top_5
# return the 5 rows from netflix_data that have the largest values in the column "Hours Viewed".
# Out:
#                                                  Title Available Globally?  \
# 0                            The Night Agent: Season 1                 Yes
# 1                            Ginny & Georgia: Season 2                 Yes
# 18227  King the Land: Limited Series // 킹더랜드: 리미티드 시리즈                 Yes
# 2                   The Glory: Season 1 // 더 글로리: 시즌 1                 Yes
# 18214                              ONE PIECE: Season 1                 Yes
#
#       Release Date  Hours Viewed Language Indicator Content Type  \
# 0       2023-03-23   812100000.0            English         Show
# 1       2023-01-05   665100000.0            English         Show
# 18227   2023-06-17   630200000.0             Korean        Movie
# 2       2022-12-30   622800000.0             Korean         Show
# 18214   2023-08-31   541900000.0            English         Show
#
#        Release Month
# 0                  3
# 1                  1
# 18227              6
# 2                 12
# 18214              8

# %%
monthly_viewership_pivot_table=netflix_data.pivot_table(index='Release Month',values='Hours Viewed',
columns='Content Type',aggfunc='sum')
monthly_viewership_pivot_table
# Out:
# Content Type          Movie          Show
# Release Month
# 1              2.275900e+09  4.995700e+09
# 2              1.654400e+09  5.449300e+09
# 3              2.109400e+09  5.327700e+09
# 4              2.757600e+09  4.108100e+09
# 5              2.520500e+09  4.574100e+09
# 6              3.135800e+09  5.386200e+09
# 7              1.615700e+09  4.909100e+09
# 8              2.186400e+09  4.631400e+09
# 9              2.092300e+09  5.169900e+09
# 10             3.400400e+09  4.722800e+09
# 11             1.866900e+09  5.882600e+09
# 12             2.554900e+09  7.500900e+09

# %%
fig = go.Figure()
for n in monthly_viewership_pivot_table.columns:
    fig.add_trace(go.Scatter(
        x=monthly_viewership_pivot_table.index,
        y=monthly_viewership_pivot_table[n],
        mode='lines+markers',name=n,marker_color=['skyblue','salmon']
    ))

    fig.update_layout(title=' Viewership trends by Content Type',
    xaxis_title='Month',yaxis_title='Total Hours Viewed (in billions)',
    xaxis=dict(tickmode='array', tickvals= list(range(1,13)),
    ticktext=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
            'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
    ),width=800,legend_title='Content Type',height=700
    )

fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="6bbdc8ed-79ea-49d4-83c2-75420c4792bd" class="plotly-graph-div" style="height:700px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("6bbdc8ed-79ea-49d4-83c2-75420c4792bd")) {                    Plotly.newPlot(                        "6bbdc8ed-79ea-49d4-83c2-75420c4792bd",                        [{"marker":{"color":["skyblue","salmon"]},"mode":"lines+markers","name":"Movie","x":{"dtype":"i1","bdata":"AQIDBAUGBwgJCgsM"},"y":{"dtype":"f8","bdata":"AAAATO\u002f04EEAAAAACafYQQAAAPC4bt9BAAAAYLSL5EEAAADkeMfiQQAAAFgQXedBAAAACGgT2EEAAAAgOkrgQQAAALh9Ld9BAAAAkL9V6UEAAACIqNHbQQAAAMQVCeNB"},"type":"scatter"},{"marker":{"color":["skyblue","salmon"]},"mode":"lines+markers","name":"Show","x":{"dtype":"i1","bdata":"AQIDBAUGBwgJCgsM"},"y":{"dtype":"f8","bdata":"AAAAUkWc8kEAAACC20z0QQAAAALk2PNBAAAANJSb7kEAAACiMwrxQQAAADyuEPRBAAAAvq5J8kEAAADk2EDxQQAAAJ5mQvNBAAAAWAOY8UEAAACkFer1QQAAAGpq8ftB"},"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo", ...

# %% [markdown]
# ## explore the total viewership hours distributed across different release seasons

# %%
def get_season(month):
    if month in [12,1,2]:
        return 'Winter'
    elif month in [3,4,5]:
        return 'Spring'
    elif month in [6,7,8]:
        return 'Summer'
    else:
        return 'Fall'

# %%
netflix_data['Release Season'] = netflix_data['Release Month'].apply(get_season)
netflix_data
# Out:
#                                               Title Available Globally?  \
# 0                         The Night Agent: Season 1                 Yes
# 1                         Ginny & Georgia: Season 2                 Yes
# 2                The Glory: Season 1 // 더 글로리: 시즌 1                 Yes
# 3                               Wednesday: Season 1                 Yes
# 4               Queen Charlotte: A Bridgerton Story                 Yes
# ...                                             ...                 ...
# 24807            We Are Black and British: Season 1                  No
# 24808             Whitney Cummings: Can I Touch It?                 Yes
# 24809                       Whitney Cummings: Jokes                  No
# 24810  Whose Vote Counts, Explained: Limited Series                 Yes
# 24811   Zach Galifianakis: Live at the Purple Onion                  No
#
#       Release Date  Hours Viewed Language Indicator Content Type  \
# 0       2023-03-23   812100000.0            English         Show
# 1       2023-01-05   665100000.0            English         Show
# 2       2022-12-30   622800000.0             Korean         Show
# 3       2022-11-23   507700000.0            English         Show
# 4       2023-05-04   503000000.0            English        Movie
# ...            ...           ...                ...          ...
# 24807          NaT      100000.0            English         Show
# 24808   2019-07-30      100000.0            English        Movie
# 24809   2022-07-26      100000.0            English        Movie
# 24810   2020-09-28      100000.0            English        Movie
# 24811          NaT      100000.0            English        Movie
#
#        Release Month Release Season
# 0                  3         Spring
# 1                  1         Winter
# 2                 12         Winter
# 3                 11           Fall
# 4                  5         Spring
# ...              ...            ...
# 24807           <NA>           Fall
# 24808              7         Summer
# 24809              7         Summer
# 24810              9           Fall
# 24811           <NA>           Fall
#
# [24812 rows x 8 columns]

# %%
seasonal_viewership=netflix_data.groupby('Release Season')['Hours Viewed'].sum()
order = ['Winter', 'Spring', 'Summer', 'Fall']
seasonal_viewership=seasonal_viewership.reindex(order)

# %%
fig=go.Figure(data=[go.Bar(x=seasonal_viewership.index,y=seasonal_viewership.values,
marker_color='magenta')])

fig.update_layout(
title='Viewership trends by Release Season', title_x=0.5,
xaxis_title='Season', yaxis_title='Total Hours Viewed (in billions)',
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="2b4dc469-04bb-47fe-960d-e418a82fc508" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("2b4dc469-04bb-47fe-960d-e418a82fc508")) {                    Plotly.newPlot(                        "2b4dc469-04bb-47fe-960d-e418a82fc508",                        [{"marker":{"color":"magenta"},"x":["Winter","Spring","Summer","Fall"],"y":{"dtype":"f8","bdata":"AACAAdTAFkIAAACnie0TQgAAAEftXBRCAAAAcqoeNUI="},"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"scattergl":[{"type":"scattergl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter3d":[{"type":"scatter3d","line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outli ...
#
# var gd = document.getElementById('2b4dc469-04bb-47fe-960d-e418a82fc508');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = w

# %% [markdown]
# ## analyze the number of content releases and their viewership hours across months

# %%
monthly_content_relase=netflix_data['Release Month'].value_counts().sort_index()
monthly_content_relase
# Out:
# Release Month
# 1     608
# 2     560
# 3     690
# 4     647
# 5     624
# 6     670
# 7     631
# 8     674
# 9     739
# 10    802
# 11    734
# 12    787
# Name: count, dtype: Int64

# %%
monthly_content_relase=netflix_data['Release Month'].value_counts().sort_index()
monthly_viewership = netflix_data.groupby('Release Month')['Hours Viewed'].sum()

fig = go.Figure()
fig.add_trace(go.Bar(
    x=monthly_content_relase.index,y=monthly_content_relase.values,
    marker_color='goldenrod',name='Number of Releases',opacity=0.7,
    yaxis='y1' #By default, a figure has one y-axis, called y1.
))
fig.add_trace(go.Scatter(x=monthly_viewership.index,y=monthly_viewership.values,
    marker_color='red',yaxis='y2',name='viewership hours',mode='lines+markers'
    ))

fig.update_layout(title='Monthly Release Patterns and Viewership Hours (2023)',
title_x=0.5,xaxis_title='month',
xaxis=dict(tickmode='array',tickvals=list(range(1,13)),
ticktext=['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 
        'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']),
yaxis=dict( title='Number of Releases',
showgrid=False,side='left'),
yaxis2=dict( title='Number of Releases',
showgrid=False,side='right',
overlaying='y'), #overlaying='y' means Place (y2) on top of the first y-axis 
legend=dict(x=1.08, y=1,
orientation='v',xanchor='left')
, width=830)


fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="a588b755-156a-4472-9435-e11e35372eb8" class="plotly-graph-div" style="height:525px; width:830px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("a588b755-156a-4472-9435-e11e35372eb8")) {                    Plotly.newPlot(                        "a588b755-156a-4472-9435-e11e35372eb8",                        [{"marker":{"color":"goldenrod"},"name":"Number of Releases","opacity":0.7,"x":{"dtype":"i1","bdata":"AQIDBAUGBwgJCgsM"},"y":{"dtype":"i2","bdata":"YAIwArIChwJwAp4CdwKiAuMCIgPeAhMD"},"yaxis":"y","type":"bar"},{"marker":{"color":"red"},"mode":"lines+markers","name":"viewership hours","x":{"dtype":"i1","bdata":"AQIDBAUGBwgJCgsM"},"y":{"dtype":"f8","bdata":"AAAA+LwW+0EAAADCnXb6QQAAAD6StPtBAAAASqST+UEAAAAU8G36QQAAAGg2v\u002f9BAAAAwIhO+EEAAAD09WX5QQAAAAzGDftBAAAAIONC\u002fkEAAADGf978QQAAAKb6ugJC"},"yaxis":"y2","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type": ...

# %%
netflix_data['Release day'] = netflix_data['Release Date'].dt.day_name()
weekday_releases=netflix_data['Release day'].value_counts().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])
weekday_viewership =netflix_data.groupby('Release day')['Hours Viewed'].sum().reindex(
    ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday'])

# %%
fig = go.Figure()
fig.add_trace(go.Bar(
    x=weekday_releases.index,
    y=weekday_releases.values,
    marker_color='blue',opacity=0.5,
    yaxis='y',name='Number of releases'
))
fig.add_trace(go.Scatter(
    x=weekday_viewership.index,
    y=weekday_viewership.values,
    line=dict(color='red'),
    marker=dict(color='red'),
    mode='lines+markers',
    name='Viewership hours',
    yaxis='y2'
))
fig.update_layout(
title='Weekly Release Patterns and Viewership Hours',
xaxis=dict(
        title='Day of the Week',
        categoryorder='array',
        categoryarray=['Monday', 'Tuesday', 'Wednesday', 'Thursday',
                    'Friday', 'Saturday', 'Sunday']
),

yaxis =dict(
    title='Number of Releases',
    showgrid=False,side='left',
    showline=True,          
        linewidth=2,
        linecolor='black',
        ticks='outside',
        tickfont=dict(color='red')
),
yaxis2 =dict(
    title='Total Hours Viewed (in billions)',
    showgrid=False,side='right',
    overlaying='y',
    showline=True,         
        linewidth=2,
        linecolor='blue',
        ticks='outside',
        tickfont=dict(color='blue'),   
    )

,legend=dict(
    x=1.09,y=1
),width =800, height =600
)
fig.show()
# Out:
# <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                    <div id="b8f8a954-53c9-4c23-bc66-20365847991a" class="plotly-graph-div" style="height:600px; width:800px;"></div>            <script type="text/javascript">                window.PLOTLYENV=window.PLOTLYENV || {};                                if (document.getElementById("b8f8a954-53c9-4c23-bc66-20365847991a")) {                    Plotly.newPlot(                        "b8f8a954-53c9-4c23-bc66-20365847991a",                        [{"marker":{"color":"blue"},"name":"Number of releases","opacity":0.5,"x":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],"y":{"dtype":"i2","bdata":"tAHjAx4FeQQXD+4AswA="},"yaxis":"y","type":"bar"},{"line":{"color":"red"},"marker":{"color":"red"},"mode":"lines+markers","name":"Viewership hours","x":["Monday","Tuesday","Wednesday","Thursday","Friday","Saturday","Sunday"],"y":{"dtype":"f8","bdata":"AAAANJx27UEAAABmn7j0QQAAADVfUw1CAAAAOC7mEkIAAABj2MshQgAAAHSHFPNBAAAAaJXW3EE="},"yaxis":"y2","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{" ...

# %% [markdown]
# ### explore specific high-impact dates for Netflix MENA in Saudi Arabia

# %%
important_dates = [
    '2023-04-21',  # Eid al-Fitr 
    '2023-04-22',  # Eid al-Fitr Holiday 
    '2023-04-23',  # Eid al-Fitr Holiday
    '2023-06-28',  # Eid al-Adha – Saudi 
    '2023-06-29',  # Eid al-Adha Holiday
    '2023-06-30',  # Eid al-Adha Holiday 
    '2023-07-19',  # Islamic New Year 
    '2023-09-23'   # Saudi National Day 
]
# convert to datetime
important_dates=pd.to_datetime(important_dates)
important_dates=important_dates.tolist()

#Check how many hours people watched Netflix on these dates?
holiday_releases=netflix_data[netflix_data['Release Date'].isin(important_dates)]
holiday_viewership = holiday_releases.groupby('Release Date')['Hours Viewed'].sum().sort_values(ascending=False)
holiday_viewership
# Out:
# Release Date
# 2023-06-29    422100000.0
# 2023-04-21    333300000.0
# 2023-06-30    269900000.0
# 2023-06-28     60100000.0
# 2023-07-19     54400000.0
# 2023-04-22      7700000.0
# Name: Hours Viewed, dtype: float64

# %%
# check for content releases close to these significant holidays (within a 3-day window)
holiday_release = netflix_data[
    netflix_data['Release Date'].apply(
        lambda x :any ((x- date ).days in range (-3,4) for date in important_dates)
    )]
# aggregate viewership hours for releases near significant holidays
holiday_viewership = holiday_release.groupby('Release Date')['Hours Viewed'].sum()

holiday_release[['Title', 'Release Date', 'Hours Viewed']]
# Out:
#                                                    Title Release Date  \
# 18                                The Diplomat: Season 1   2023-04-20
# 31     The Marked Heart: Season 2 // Pálpito: Tempora...   2023-04-19
# 48     The Good Bad Mother: Limited Series // 나쁜엄마: 리...   2023-04-26
# 84     Welcome to Eden: Season 2 // Bienvenidos a Edé...   2023-04-21
# 161                             Rough Diamonds: Season 1   2023-04-21
# ...                                                  ...          ...
# 21367                     Ada Twist, Scientist: Season 4   2023-04-22
# 21759  Hard Broken: Limited Series // كسرة قلب: Limit...   2023-09-20
# 22170  Love After Music: Season 1 // El amor después ...   2023-04-26
# 22828  Tooth Pari: When Love Bites: Limited Series //...   2023-04-20
# 23010  Risqué Business: Japan: Season 1 // 성+인물: 일본 편...   2023-04-25
#
#        Hours Viewed
# 18      214100000.0
# 31      174300000.0
# 48      148600000.0
# 84      104500000.0
# 161      72800000.0
# ...             ...
# 21367     2800000.0
# 21759     1900000.0
# 22170     1600000.0
# 22828     1200000.0
# 23010      800000.0
#
# [69 rows x 3 columns]
